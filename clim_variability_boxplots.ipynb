# %%
df
# Out:
#            income source  sensitivity
# 0             Low   CSIF     0.639909
# 1    Lower middle    FAO     0.137087
# 2    Upper middle   CSIF     0.063252
# 3            High    FAO     0.384608
# 4             Low   CSIF     0.232047
# ..            ...    ...          ...
# 195          High    FAO     0.967354
# 196           Low   CSIF     0.133738
# 197  Lower middle    FAO     0.771320
# 198  Upper middle   CSIF     0.021998
# 199          High    FAO     0.895298
#
# [200 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Example long-format data
df = pd.DataFrame({
    "income": ["Low", "Lower middle", "Upper middle", "High"] * 50,
    "source": ["CSIF", "FAO"] * 100,  # alternating CSIF/FAO
    "sensitivity": np.random.rand(200)  # toy values
})

plt.figure(figsize=(8,5))
sns.boxplot(
    data=df,
    x="income", y="sensitivity",
    hue="source",
    palette={"CSIF": "red", "FAO": "black"},
    width=0.6
)
sns.stripplot(
    data=df,
    x="income", y="sensitivity",
    hue="source",
    dodge=True, jitter=True,
    palette={"CSIF": "red", "FAO": "black"},
    alpha=0.7, size=4, linewidth=0.5, edgecolor="k"
)

plt.ylabel("SM sensitivity averaged across all crop models")
plt.xlabel("")
plt.legend(title="", loc="upper right")
plt.tight_layout()
plt.show()

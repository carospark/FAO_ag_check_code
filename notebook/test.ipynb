# %%
import pandas as pd
import os



df = pd.read_csv("/Users/caropark/FAO_ag_check_code/data/yields.csv")
df
# Out:
#          year  fao_idx cropname   csif_og                             country  \
# 0      2000.0     11.0   Barley  0.030731                         Afghanistan
# 1      2001.0     11.0   Barley  0.026081                         Afghanistan
# 2      2002.0     11.0   Barley  0.043133                         Afghanistan
# 3      2003.0     11.0   Barley  0.039029                         Afghanistan
# 4      2004.0     11.0   Barley  0.030863                         Afghanistan
# ...       ...      ...      ...       ...                                 ...
# 41871  2019.0    159.0     Yams  0.283696  Venezuela (Bolivarian Republic of)
# 41872  2020.0    159.0     Yams  0.260898  Venezuela (Bolivarian Republic of)
# 41873  2021.0    159.0     Yams  0.334304  Venezuela (Bolivarian Republic of)
# 41874  2022.0    159.0     Yams  0.313464  Venezuela (Bolivarian Republic of)
# 41875  2023.0    159.0     Yams  0.321954  Venezuela (Bolivarian Republic of)
#
# ...

# %%
max(df['year'])
# Out:
# 2023.0
